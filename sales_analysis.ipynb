# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
df=pd.read_csv("E:/elevate labs internship/sample_sales_data_full.csv")
print(df.head())
# Out:
#          Date Product Region  Sales  Units Sold  Unit Price
# 0  2024-01-01       A  North   1000         100          10
# 1  2024-02-01       B  South   1200         120          10
# 2  2024-03-01       C   East   1100         110          10
# 3  2024-04-01       A   West   1300         130          10
# 4  2024-05-01       B  North   1250         125          10

# %%
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 12 entries, 0 to 11
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Date        12 non-null     object
#  1   Product     12 non-null     object
#  2   Region      12 non-null     object
#  3   Sales       12 non-null     int64
#  4   Units Sold  12 non-null     int64
#  5   Unit Price  12 non-null     int64
# dtypes: int64(3), object(3)
# memory usage: 708.0+ bytes
# None

# %%
print(df.describe())
# Out:
#              Sales  Units Sold  Unit Price
# count    12.000000   12.000000        12.0
# mean   1320.833333  132.083333        10.0
# std     187.638837   18.763884         0.0
# min    1000.000000  100.000000        10.0
# 25%    1187.500000  118.750000        10.0
# 50%    1325.000000  132.500000        10.0
# 75%    1462.500000  146.250000        10.0
# max    1600.000000  160.000000        10.0

# %%
sns.set(style='whitegrid')

# %%
df.isnull().sum()
# Out:
# Date          0
# Product       0
# Region        0
# Sales         0
# Units Sold    0
# Unit Price    0
# dtype: int64

# %%
df['Date']=pd.to_datetime(df['Date'])

# %%
product_sales=df.groupby('Product')['Sales'].sum().sort_values(ascending=False)
print(product_sales)
# Out:
# Product
# B    5350
# C    5300
# A    5200
# Name: Sales, dtype: int64

# %%
sales_by_region=df.groupby('Region')['Sales'].sum()
print(sales_by_region)
# Out:
# Region
# East     4050
# North    3700
# South    3850
# West     4250
# Name: Sales, dtype: int64

# %%
monthly_sales = df.groupby(df['Date'].dt.to_period('M'))['Sales'].sum()
print(monthly_sales)
# Out:
# Date
# 2024-01    1000
# 2024-02    1200
# 2024-03    1100
# 2024-04    1300
# 2024-05    1250
# 2024-06    1150
# 2024-07    1400
# 2024-08    1350
# 2024-09    1450
# 2024-10    1500
# 2024-11    1550
# 2024-12    1600
# Freq: M, Name: Sales, dtype: int64

# %%
product_sales.plot(kind='bar', title='Total Sales by Product', color='skyblue')
plt.ylabel('Sales Amount')
plt.xticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
sales_by_region.plot(kind='pie', autopct='%1.1f%%', title='Sales by Region', figsize=(6, 6))
plt.ylabel('')
plt.tight_layout()
plt.show()

# %%
monthly_sales.plot(kind='line', marker='o', title='Monthly Sales Trend', color='green')
plt.ylabel('Sales Amount')
plt.xlabel('Month')
plt.tight_layout()
plt.show()
